# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.314856  0.042649 -1.844702
# b       NaN       NaN       NaN
# c  1.329819  0.695977 -0.556387
# d  0.536663  0.631948 -2.051091
# e       NaN       NaN       NaN
# f -0.488998  0.427811 -1.509319
#
#
# Dropped DataFrame
#          one       two     three
# a  0.314856  0.042649 -1.844702
# c  1.329819  0.695977 -0.556387
# d  0.536663  0.631948 -2.051091
# f -0.488998  0.427811 -1.509319

# %%
f=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.314856  0.042649 -1.844702
# b       NaN       NaN       NaN
# c  1.329819  0.695977 -0.556387
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.314856  0.042649 -1.844702
# b  0.000000  0.000000  0.000000
# c  1.329819  0.695977 -0.556387

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
 'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -0.531706 -0.528020  0.477852
# b       NaN       NaN       NaN
# c -2.452836 -0.509268 -1.221042
# d  1.048338 -0.809275 -1.508125
# e       NaN       NaN       NaN
# f -0.558970 -0.281594 -0.963154
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
 columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  1.062344  0.243057  0.772006
# b       NaN       NaN       NaN
# c -0.112374  2.700371 -0.768861
# d  0.136264 -0.054147 -0.872610
# e       NaN       NaN       NaN
# f -1.279226 -0.227639  0.582582
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  1.062344  0.243057  0.772006
# b -0.112374  2.700371 -0.768861
# c -0.112374  2.700371 -0.768861
# d  0.136264 -0.054147 -0.872610
# e -1.279226 -0.227639  0.582582
# f -1.279226 -0.227639  0.582582
